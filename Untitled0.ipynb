# %%
name = "Pune"

# %%
print(name)
# Out:
# Pune

# %%
name.startswith("P")
# Out:
# True

# %%
name.startswith(" p")
# Out:
# False

# %%
name.endswith(" Pune")
# Out:
# False

# %%
name.endswith("e")
# Out:
# True

# %%
name.lstrip()
# Out:
# 'Pune'

# %%
name.endswith("e ")
# Out:
# False

# %%
name.rstrip()
# Out:
# 'Pune'

# %%
name.strip()
# Out:
# 'Pune'

# %%
name
# Out:
# 'Pune'

# %%
len(name)
# Out:
# 4

# %%
name.replace('u' , 'oo')
# Out:
# 'Poone'

# %%
## Operators

# %%
# arithmetic

# %%
a = 5
b = 17

# %%
a + b
# Out:
# 22

# %%
a - b
# Out:
# -12

# %%
a / b
# Out:
# 0.29411764705882354

# %%
b / a
# Out:
# 3.4

# %%
a * b
# Out:
# 85

# %%
a ** b # raise to
# Out:
# 762939453125

# %%
b // a# flooe div
# Out:
# 3

# %%
b % a
# Out:
# 2

# %%
## assignment operator

# %%
z = 5

# %%
z
# Out:
# 5

# %%
z = z + 3
z
# Out:
# 8

# %%
z += 3
z
# Out:
# 8

# %%
z -= 3
z
# Out:
# -1

# %%
# comparison

# %%
a
# Out:
# 5

# %%
b
# Out:
# 17

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a >= b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
# logical operators

# %%
a = True

# %%
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
# identity operators -> is, is not

# %%
a = 5
b = 5

# %%
id (a), id(b)
# Out:
# (11645480, 11645480)

# %%
a is b
# Out:
# True

# %%
a = [3,4]
b = [3,4]

# %%
id (a), id (b)
# Out:
# (136187007279296, 136187002885184)

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z = a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(2)
a
# Out:
# [3, 4, 10, 10, 2]

# %%
z
# Out:
# [3, 4, 10, 10, 2]

# %%
# membership selection operator -> in

# %%
l = [ 4, 6, 7, 9]

# %%
6 in l
# Out:
# True

# %%
2 in l
# Out:
# False

# %%
2 not in l
# Out:
# True

# %%
# precedence and association

# %%
# BODMAS

# %%
5 + 2 - 10
# Out:
# -3

# %%
( 4 - 2) ** 2
# Out:
# 4

# %%
2 ** 2 ** 3
# Out:
# 256

# %%
2 ** 3 // 2 # floor div
# Out:
# 4

# %%
# print function

# %%
name = "Geeta"
marks = 76.57

# %%
# my name is Geeta and marks are 76.57

# %%
print(name)
# Out:
# Geeta

# %%
print("my name is %s and marks are %i" %(name, marks))
# Out:
# my name is Geeta and marks are 76

# %%
print("my name is", name, "and marks are", marks)
# Out:
# my name is Geeta and marks are 76.57

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is Geeta and marks are 76.57

# %%
# dir and help

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
# ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
chr(35)
# Out:
# '#'

# %%
chr(25)
# Out:
# '\x19'

# %%
# type casting

# %%
num1 = 25
num2 = 24.5
num3 = "vk"

# %%
type(num1)
# Out:
# int

# %%
float(num1)
# Out:
# 25.0

# %%
int(num2)
# Out:
# 24

# %%
str(num2)
# Out:
# '24.5'

# %%
str(num1)
# Out:
# '25'

# %%
# user input

# %%
a = input("enter the number")
# Out:
# enter the number2

# %%
# write the program for addition of two numbers  using user input

# %%
a = int(input("enter the num1:"))
b = int(input("enter the num2:"))
c = a + b
print("addition is ->", c)
# Out:
# enter the num1:15
# enter the num2:12
# addition is -> 27

# %%
"""
read the time in second as user input
and print the time in the format as hour:minutes:seconds

eg ...
input -> 125 second
output -> 00:02:05

""";

# %%
second = int(input(enter the time:))
